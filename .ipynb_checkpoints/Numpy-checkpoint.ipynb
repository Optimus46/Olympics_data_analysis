# %%
import numpy as np

# %%
my_lst=[1,2,3,4]

# %%
arr=np.array(my_lst)

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr)
# Out:
# [1 2 3 4]

# %%
my_list1=[1,2,3,4]
my_list2=[8,7,6,5]
my_list3=[3,4,5,7]

arr1=np.array([my_list1,my_list2,my_list3])

# %%
arr1
# Out:
# array([[1, 2, 3, 4],
#        [8, 7, 6, 5],
#        [3, 4, 5, 7]])

# %%
arr1.shape
# Out:
# (3, 4)

# %%
arr1.reshape(4,3)
# Out:
# array([[1, 2, 3],
#        [4, 8, 7],
#        [6, 5, 3],
#        [4, 5, 7]])

# %%
arr1.shape
# Out:
# (3, 4)

# %%
arr1[0][1]
# Out:
# np.int64(2)

# %%
arr1[0]
# Out:
# array([1, 2, 3, 4])

# %%
arr1[0,0]
arr1[0,2]
# Out:
# np.int64(3)

# %%
print(arr1[0,0])
# Out:
# 1

# %%
arr1[0:2,:]
# Out:
# array([[1, 2, 3, 4],
#        [8, 7, 6, 5]])

# %%
arr1
# Out:
# array([[1, 2, 3, 4],
#        [8, 7, 6, 5],
#        [3, 4, 5, 7]])

# %%
arr1[1:3,2:4]
# Out:
# array([[6, 5],
#        [5, 7]])

# %%
arr1[1:2,1:3]
# Out:
# array([[7, 6]])

# %%
arr2=np.arange(0,10,step=2)

# %%
arr2
# Out:
# array([0, 2, 4, 6, 8])

# %%
arr1
# Out:
# array([[1, 2, 3, 4],
#        [8, 7, 6, 5],
#        [3, 4, 5, 7]])

# %%
print(arr1.ndim)
# Out:
# 2

# %%
# Copy (deep copy)
copy_arr = arr1.copy()
copy_arr[1, 1] = 77   # change element at row 1, col 1
print("Original after copy change:\n", arr1)
print("Copy:\n", copy_arr)
# Out:
# Original after copy change:
#  [[1 2 3 4]
#  [8 7 6 5]
#  [3 4 5 7]]
# Copy:
#  [[ 1  2  3  4]
#  [ 8 77  6  5]
#  [ 3  4  5  7]]

# %%
print(arr1+10) #broadcasting
# Out:
# [[11 12 13 14]
#  [18 17 16 15]
#  [13 14 15 17]]

# %%
print(arr1)
# Out:
# [[1 2 3 4]
#  [8 7 6 5]
#  [3 4 5 7]]

# %%
#useful for eda
val=2
result=arr1[arr1>2]
print(result)
# Out:
# [3 4 8 7 6 5 3 4 5 7]

# %%
result.reshape(2,5)
# Out:
# array([[3, 4, 8, 7, 6],
#        [5, 3, 4, 5, 7]])

# %%
np.ones(4,dtype=int)
# Out:
# array([1, 1, 1, 1])

# %%
np.random.rand(3,3) #selected between 0 and 1 randomn distribution
# Out:
# array([[0.59332788, 0.57317044, 0.22789017],
#        [0.79291411, 0.62949813, 0.38580109],
#        [0.28428967, 0.23712536, 0.75191692]])

# %%
np.random.randint(0,100,8).reshape(2,4)
# Out:
# array([[25, 20, 80, 65],
#        [ 0, 38, 44, 21]], dtype=int32)
